# %%
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet, SGDRegressor
import numpy as np
import pandas as pd
import pylab as pl

# %%
weather_dataset1 = pd.read_csv('wwo_normalized_manila\\worldweatheronline_normalized_manila_2015_1day.csv', index_col=[0], parse_dates=[0], skipinitialspace=True)
# weather_dataset2 = pd.read_csv('wwo_normalized_manila\\worldweatheronline_normalized_manila_2016_1day.csv', index_col=[0], parse_dates=[0], skipinitialspace=True)
# weather_dataset3 = pd.read_csv('wwo_normalized_manila\\worldweatheronline_normalized_manila_2017_1day.csv', index_col=[0], parse_dates=[0], skipinitialspace=True)
# weather_dataset = []
# weather_dataset.append(weather_dataset1)
# weather_dataset.append(weather_dataset2)
# weather_dataset.append(weather_dataset3)
# weather_dataset = pd.concat(weather_dataset)
# weather_dataset

# Remove unused columns and reorder 
weather_dataset = weather_dataset1[['precipMM', 'tempC', 'windspeedKmph', 'cond', 'humidity', 'visibility', 'pressure', 'cloudcover', 'heatIndexC', 'dewPointC', 'windChillC', 'windGustKmph', 'feelsLikeC']]
weather_dataset
# Out:
#             precipMM     tempC  windspeedKmph      cond  humidity  visibility  \
# 2015-01-01  0.020649  0.232552       0.350260  0.565789  0.810009    0.968750
# 2015-01-02  0.000000  0.231250       0.441406  0.585526  0.765097    1.000000
# 2015-01-03  0.001106  0.241667       0.305398  0.631579  0.808877    1.000000
# 2015-01-04  0.000369  0.278385       0.205374  0.580044  0.838240    1.000000
# 2015-01-05  0.001106  0.323698       0.177083  0.399123  0.842995    0.848307
# 2015-01-06  0.001106  0.357813       0.160393  0.399123  0.806914    0.771484
# 2015-01-07  0.001659  0.270573       0.180279  0.414474  0.822992    0.869792
# 2015-01-08  0.000000  0.222917       0.320786  0.645833  0.738074    1.000000
# 2015-01-09  0.004978  0.185417       0.312263  0.559211  0.800121    0.921875
# 2015-01-10  0.000369  0.183854       0.310133  0.655702  0.721014    1.000000
# 2015-01-11  0.001659  0.174479       0.278527  0.611842  0.758228    1.000000
# 2015-01-12  0.000922  0.213281       0.296046  0.486842  0.784647    1.000000
# 2015-01-13  0.002397  0.208854       0.264086  0.399123  0.786156    0.921875
# 2015-01-14  0.000369  0.288281       0.181818  0.474781  0.802612    0.848307
# 2015-01-15  0.000369  0.281250       0.213423  0.399123  0.795139    0.771484
# 2015-01-16  0.000000  0.253385       0.249408  0.464912  0.746150    1.000000
# 2015-01-17  0.000000  0.206250       0.233546  0.447368  0.687726    1.000000
# 2015-01-18  0.008919  0.163281       0.328598  0.541667  0.618961    0.854167
# 2015-01-19  0.000115  0.322396       0.087358  0.480263  0.644248    1.000000
# 2015-01-20  0.000000  0.377083       0.117069  0.489035  0.610734    1.000000
# 2015-01-21  0.000254  0.413281       0.071378  0.589912  0.616923    1.000000
# 2015-01-22  0.002282  0.360938       0.210582  0.713268  0.610583    1.000000
# 2015-01-23  0.000968  0.222135       0.351918  0.560855  0.639719    1.000000
# 2015-01-24  0.000000  0.216667       0.338778  0.353070  0.624849    1.000000
# 2015-12-26      0.141131    0.372486
# 2015-12-27      0.136357    0.440733
# 2015-12-28      0.153067    0.403197
# 2015-12-29      0.155744    0.310704
# 2015-12-30      0.148944    0.357938
# 2015-12-31      0.204813    0.340278
#
# [365 rows x 13 columns]

# %%
x = weather_dataset.loc[:, weather_dataset.columns != 'precipMM'].values.tolist()
y = weather_dataset['precipMM']

# %%
# In order to do multiple regression we need to add a column of 1s for x0
x = np.array([np.concatenate((v,[1])) for v in x])

# %%
# First 10 elements of the data
print(x[:10])
# Out:
# [[ 0.23255208  0.35026042  0.56578947  0.81000906  0.96875     0.77550287
#    0.33390625  0.26813937  0.5693109   0.23671875  0.28580729  0.26813937
#    1.        ]
#  [ 0.23125     0.44140625  0.58552632  0.76509662  1.          0.84823994
#    0.30880208  0.24712644  0.50440705  0.23125     0.33492477  0.24712644
#    1.        ]
#  [ 0.24166667  0.30539773  0.63157895  0.80887681  1.          0.82650862
#    0.48442708  0.27873563  0.57051282  0.24166667  0.22771991  0.27873563
#    1.        ]
#  [ 0.27838542  0.20537405  0.58004386  0.83823973  1.          0.76239224
#    0.41854167  0.33189655  0.61217949  0.27838542  0.1733941   0.32758621
#    1.        ]
#  [ 0.32369792  0.17708333  0.39912281  0.84299517  0.84830729  0.74281609
#    0.36114583  0.3908046   0.68589744  0.32369792  0.15024595  0.3908046
#    1.        ]
#  [ 0.3578125   0.16039299  0.39912281  0.80691425  0.77148438  0.73994253
#    0.28083333  0.41451149  0.66225962  0.3578125   0.13621238  0.41451149
#    1.        ]
#  [ 0.27057292  0.18027936  0.41447368  0.82299215  0.86979167  0.75969828
#    0.31770833  0.32255747  0.61217949  0.27057292  0.14489294  0.32255747
#    1.        ]
#  [ 0.22291667  0.32078598  0.64583333  0.73807367  1.          0.83243534
#    0.26041667  0.24371408  0.45072115  0.22291667  0.26439525  0.24371408
#    1.        ]
#  [ 0.18541667  0.31226326  0.55921053  0.80012077  0.921875    0.86063218
#    0.54583333  0.21641523  0.48397436  0.18541667  0.24573206  0.21641523
#    1.        ]
#  [ 0.18385417  0.31013258  0.65570175  0.72101449  1.          0.84482759
#    0.33265625  0.20258621  0.38020833  0.18385417  0.25651042  0.18372845
#    1.        ]]

# %%
# First 10 elements of the response variable
print(y[:10])
# Out:
# 2015-01-01    0.020649
# 2015-01-02    0.000000
# 2015-01-03    0.001106
# 2015-01-04    0.000369
# 2015-01-05    0.001106
# 2015-01-06    0.001106
# 2015-01-07    0.001659
# 2015-01-08    0.000000
# 2015-01-09    0.004978
# 2015-01-10    0.000369
# Name: precipMM, dtype: float64

# %% [markdown]
# ## Multiple Linear Regression

# %%
# Create linear regression object
linreg = LinearRegression()

# Train the model using the training sets
linreg.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Let's see predictions for the first 10 instances
print(linreg.predict(x[:10]) )
# Out:
# [ 0.00819509 -0.00423463 -0.0159446  -0.00629442  0.05301928  0.07928315
#   0.03762307 -0.00278248  0.01683303 -0.00650634]

# %%
p = linreg.predict(x)

# Compute RMSE and r2_score on training data
var_r2score = r2_score(y, p)
rmse_train = np.sqrt(mean_squared_error(y, p))

print("R2 score", var_r2score)
print("RMSE", rmse_train)
# Out:
# R2 score 0.909196839809
# RMSE 0.0164302855608

# %%
# We can view the regression coefficients
print( 'Regression Coefficients: \n', linreg.coef_)
# Out:
# Regression Coefficients:
#  [  1.33381365e+00  -3.67368830e-01  -3.23742027e-02  -2.48344771e-02
#   -3.46084678e-01   6.40796947e-04  -3.88745727e-03   2.42171019e-02
#    2.84437518e-02  -1.31231108e+00   5.67364615e-01  -1.41082897e-02
#    0.00000000e+00]

# %%
# Plot outputs
# %matplotlib inline
pl.plot(p, y,'ro')
pl.plot([0,0.4],[0,0.4], 'g-')
pl.xlabel('predicted')
pl.ylabel('real')
pl.show()

# %% [markdown]
# ## train_test_split

# %%
# Splitting training and testing data
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.33, shuffle=False)

# Create linear regression object
linreg = LinearRegression()

# Train the model using the training sets
linreg.fit(X_train,Y_train)

# Let's see predictions for the first 10 instances
print(linreg.predict(X_test[:10]) )
# Out:
# [ 0.0296531   0.03292058  0.03221698  0.03054325  0.01890589  0.00451707
#   0.03845005  0.01003576  0.0454661   0.05862153]

# %%
p = linreg.predict(X_test)

# Compute RMSE and r2_score on training data
r2score_train = r2_score(Y_test, p)
rmse_train = np.sqrt(mean_squared_error(Y_test, p))

print("R2 score", r2score_train)
print("RMSE", rmse_train)
# Out:
# R2 score 0.818807886987
# RMSE 0.0281699271857

# %%
# We can view the regression coefficients
print( 'Regression Coefficients: \n', linreg.coef_)
# Out:
# Regression Coefficients:
#  [-0.3588366  -0.69885125  0.0029847  -0.17296988 -0.22105346  0.01416706
#  -0.00594344 -0.3645611   0.16093909  0.33871665  0.92663534  0.23538938
#   0.        ]

# %%
# Plot outputs
# %matplotlib inline
pl.plot(p, Y_test,'ro')
pl.plot([0,0.4],[0,0.4], 'g-')
pl.xlabel('predicted')
pl.ylabel('real')
pl.show()

# %% [markdown]
# ## 10-fold Cross Validation

# %%
# Now let's compute RMSE using 10-fold x-validation
kf = KFold(n_splits=10, shuffle=False, random_state=None)
xval_err = 0
for train_index, test_index in kf.split(x):
    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    linreg.fit(x_train, y_train)
    p = linreg.predict(x_test)
    e = p-y_test
    xval_err += np.dot(e,e)
    
rmse_10cv = np.sqrt(xval_err/len(x))

# %%
method_name = 'Simple Linear Regression'
print('Method: %s' %method_name)
print('R2 score on training: %.4f'  %r2score_train)
print('RMSE on training: %.4f'  %rmse_train)
print('RMSE on 10-fold CV: %.4f'  %rmse_10cv)
# Out:
# Method: Simple Linear Regression
# R2 score on training: 0.8188
# RMSE on training: 0.0282
# RMSE on 10-fold CV: 0.0210

# %% [markdown]
# ## Ridge Regression

# %%
# Create linear regression object with a ridge coefficient 0.5
ridge = Ridge(fit_intercept=True, alpha=0.5)

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.33, shuffle=False)
# Train the model using the training set
ridge.fit(X_train,Y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
p = ridge.predict(X_test)

# Compute RMSE and r2_score on training data
r2score_train = r2_score(Y_test, p)
rmse_train = np.sqrt(mean_squared_error(Y_test, p))

kf = KFold(n_splits=10, shuffle=False, random_state=None)
xval_err = 0
for train_index, test_index in kf.split(x):
    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    ridge.fit(x_train, y_train)
    p = ridge.predict(x_test)
    e = p-y_test
    xval_err += np.dot(e,e)
rmse_10cv = np.sqrt(xval_err/len(x))

method_name = 'Ridge Regression'
print('Method: %s' %method_name)
print('R2 score on training: %.4f' %r2score_train)
print('RMSE on training: %.4f' %rmse_train)
print('RMSE on 10-fold CV: %.4f' %rmse_10cv)
# Out:
# Method: Ridge Regression
# R2 score on training: 0.8115
# RMSE on training: 0.0287
# RMSE on 10-fold CV: 0.0216

# %% [markdown]
# ### We can try different values of alpha and observe the impact on x-validation RMSE

# %%
print('Ridge Regression')
print('alpha\t R2SCORE_train\t RMSE_train\t RMSE_10cv\n')
alpha = np.linspace(.01,20,50)
t_rmse = np.array([])
cv_rmse = np.array([])

for a in alpha:
    ridge = Ridge(fit_intercept=True, alpha=a)
    
    # computing the RMSE on training data
    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.33, shuffle=False)
    ridge.fit(X_train,Y_train)
    p = ridge.predict(X_test)
    r2score_train = r2_score(Y_test, p)
    rmse_train = np.sqrt(mean_squared_error(Y_test,p))

    kf = KFold(n_splits=10, shuffle=False, random_state=None)
    xval_err = 0
    for train_index, test_index in kf.split(x):
        x_train, x_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        ridge.fit(x_train, y_train)
        p = ridge.predict(x_test)
        e = p-y_test
        xval_err += np.dot(e,e)
    rmse_10cv = np.sqrt(xval_err/len(x))
    
    t_rmse = np.append(t_rmse, [rmse_train])
    cv_rmse = np.append(cv_rmse, [rmse_10cv])
    print('{:.3f}\t {:.4f}\t {:.4f}\t\t {:.4f}'.format(a,r2score_train,rmse_train,rmse_10cv))
# Out:
# Ridge Regression
# alpha	 R2SCORE_train	 RMSE_train	 RMSE_10cv
#
# 0.010	 0.8440	 0.0261		 0.0203
# 0.418	 0.8196	 0.0281		 0.0212
# 0.826	 0.7818	 0.0309		 0.0230
# 1.234	 0.7497	 0.0331		 0.0246
# 1.642	 0.7222	 0.0349		 0.0259
# 2.050	 0.6982	 0.0364		 0.0270
# 2.458	 0.6770	 0.0376		 0.0279
# 2.866	 0.6579	 0.0387		 0.0287
# 3.274	 0.6406	 0.0397		 0.0294
# 3.682	 0.6248	 0.0405		 0.0301
# 4.090	 0.6101	 0.0413		 0.0307
# 4.498	 0.5965	 0.0420		 0.0313
# 4.906	 0.5838	 0.0427		 0.0318
# 5.313	 0.5718	 0.0433		 0.0322
# 5.721	 0.5605	 0.0439		 0.0327
# 6.129	 0.5498	 0.0444		 0.0331
# 6.537	 0.5396	 0.0449		 0.0335
# 6.945	 0.5299	 0.0454		 0.0339
# 7.353	 0.5206	 0.0458		 0.0343
# 7.761	 0.5117	 0.0462		 0.0346
# 8.169	 0.5032	 0.0466		 0.0350
# 8.577	 0.4950	 0.0470		 0.0353
# 8.985	 0.4871	 0.0474		 0.0356
# 9.393	 0.4795	 0.0477		 0.0359
# 9.801	 0.4722	 0.0481		 0.0362
# 10.209	 0.4651	 0.0484		 0.0365
# 10.617	 0.4583	 0.0487		 0.0367
# 11.025	 0.4517	 0.0490		 0.0370
# 11.433	 0.4453	 0.0493		 0.0372
# 11.841	 0.4390	 0.0496		 0.0375
# 12.249	 0.4330	 0.0498		 0.0377
# 12.657	 0.4271	 0.0501		 0.0379
# 13.065	 0.4215	 0.0503		 0.0382
# 13.473	 0.4159	 0.0506		 0.0384
# 13.881	 0.4105	 0.0508		 0.0386
# 14.289	 0.4053	 0.0510		 0.0388
# 14.697	 0.4002	 0.0513		 0.0390
# 15.104	 0.3952	 0.0515		 0.0392
# 15.512	 0.3904	 0.0517		 0.0394
# 15.920	 0.3857	 0.0519		 0.0396
# 16.328	 0.3811	 0.0521		 0.0398
# 16.736	 0.3766	 0.0523		 0.0399
# 17.144	 0.3722	 0.0524		 0.0401
# 17.552	 0.3679	 0.0526		 0.0403
# 17.960	 0.3637	 0.0528		 0.0404
# 18.368	 0.3596	 0.0530		 0.0406
# 18.776	 0.3556	 0.0531		 0.0408
# 19.184	 0.3517	 0.0533		 0.0409
# 19.592	 0.3479	 0.0534		 0.0411
# 20.000	 0.3441	 0.0536		 0.0412

# %%
pl.plot(alpha, t_rmse, label='RMSE-Train')
pl.plot(alpha, cv_rmse, label='RMSE_XVal')
pl.legend( ('RMSE-Train', 'RMSE_XVal') )
pl.ylabel('RMSE')
pl.xlabel('Alpha')
pl.show()

# %% [markdown]
# ### To make comparisons across methods easier, let's parametrize the regression methods:

# %%
a = 0.3
for name,met in [
        ('linear regression', LinearRegression()),
        ('lasso', Lasso(fit_intercept=True, alpha=a)),
        ('ridge', Ridge(fit_intercept=True, alpha=a)),
        ('elastic-net', ElasticNet(fit_intercept=True, alpha=a))
        ]:
    
    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.33, shuffle=False)
    
    met.fit(X_train,Y_train)
    p = met.predict(X_test)
    r2score_train = r2_score(Y_test, p)
    rmse_train = np.sqrt(mean_squared_error(Y_test,p))
        
    kf = KFold(n_splits=10, shuffle=False, random_state=None)
    xval_err = 0
    for train_index, test_index in kf.split(x):
        x_train, x_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        met.fit(x_train, y_train)
        p = met.predict(x_test)
        e = p-y_test
        xval_err += np.dot(e,e)
    rmse_10cv = np.sqrt(xval_err/len(x))
    
    print('Method: %s' %name)
    print('R2 score on training: %.4f' %r2score_train)
    print('RMSE on training: %.4f' %rmse_train)
    print('RMSE on 10-fold CV: %.4f' %rmse_10cv)
    print("\n")
# Out:
# Method: linear regression
# R2 score on training: 0.8188
# RMSE on training: 0.0282
# RMSE on 10-fold CV: 0.0210
#
#
# Method: lasso
# R2 score on training: -0.0095
# RMSE on training: 0.0665
# RMSE on 10-fold CV: 0.0557
#
#
# Method: ridge
# R2 score on training: 0.8316
# RMSE on training: 0.0272
# RMSE on 10-fold CV: 0.0206
#
#
# Method: elastic-net
# R2 score on training: -0.0095
# RMSE on training: 0.0665
# RMSE on 10-fold CV: 0.0557
