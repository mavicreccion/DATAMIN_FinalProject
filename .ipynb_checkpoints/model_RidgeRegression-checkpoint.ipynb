# %%
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import Ridge
import numpy as np
import pandas as pd
import pylab as pl

# %%
weather_dataset = pd.read_csv('wwo_normalized_manila\\worldweatheronline_normalized_manila_2015_1day.csv', index_col=[0], parse_dates=[0], skipinitialspace=True)

# %% [markdown]
# # Using All Weather Variables

# %%
# Remove unused columns and reorder 
weather_dataset = weather_dataset[['precipMM', 'tempC', 'windspeedKmph', 'cond', 'humidity', 'visibility', 'pressure', 'cloudcover', 'heatIndexC', 'dewPointC', 'windChillC', 'windGustKmph', 'feelsLikeC']]

# %%
# In order to do multiple regression we need to add a column of 1s for x0
x = weather_dataset.loc[:, weather_dataset.columns != 'precipMM'].values.tolist()
x = np.array([np.concatenate((v,[1])) for v in x])

# independent variable
y = weather_dataset['precipMM']

# %% [markdown]
# ## Ridge Regression using train_test_split

# %%
# Create linear regression object with a ridge coefficient 0.5
ridge = Ridge(fit_intercept=True, alpha=-0.2)

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.33, shuffle=False)
# Train the model using the training set
ridge.fit(X_train,Y_train)

# Train the model using the training sets
ridge.fit(X_train,Y_train)
# Out:
# Ridge(alpha=-0.2, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
p = ridge.predict(X_test)

# Compute RMSE and r2_score on training data
r2score_train = r2_score(Y_test, p)
rmse_train = np.sqrt(mean_squared_error(Y_test, p))

print("R2 score", r2score_train)
print("RMSE", rmse_train)
# Out:
# R2 score 0.867734360254
# RMSE 0.0240679775671

# %%
# We can view the regression coefficients
print( 'Regression Coefficients: \n', ridge.coef_)
# Out:
# Regression Coefficients:
#  [ 0.03607703  0.10862769 -0.00117744 -0.02150626 -0.52100957 -0.00988745
#   0.01187814  0.01502162 -0.04249806  0.03641674  0.02825691  0.01624313
#  -0.        ]

# %%
# Plot outputs
# %matplotlib inline
pl.plot(p, Y_test,'ro')
pl.plot([0,0.4],[0,0.4], 'g-')
pl.xlabel('predicted')
pl.ylabel('real')
pl.show()

# %%
# Plot outputs
# %matplotlib inline
pl.plot(Y_test.index, p, label='predicted')
pl.plot(Y_test.index, Y_test, label='real')
pl.ylabel('precip')
pl.xlabel('date')
pl.legend()
pl.show()

# %% [markdown]
# ## Ridge Regression using 10-fold cross validation

# %%
# Now let's compute RMSE using 10-fold x-validation
kf = KFold(n_splits=10, shuffle=False, random_state=None)
xval_err = 0
for train_index, test_index in kf.split(x):
    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    ridge.fit(x_train, y_train)
    p = ridge.predict(x_test)
    e = p-y_test
    xval_err += np.dot(e,e)
    
rmse_10cv = np.sqrt(xval_err/len(x))

# %%
method_name = 'Ridge Regression'
print('Method: %s' %method_name)
print('R2 score on training: %.6f'  %r2score_train)
print('RMSE on training: %.6f'  %rmse_train)
print('RMSE on 10-fold CV: %.6f'  %rmse_10cv)
# Out:
# Method: Ridge Regression
# R2 score on training: 0.867734
# RMSE on training: 0.024068
# RMSE on 10-fold CV: 0.021562

# %% [markdown]
# ## Play with alpha

# %%
print('Ridge Regression')
print('alpha\t R2SCORE_train\t RMSE_train\t RMSE_10cv\n')
alpha = np.linspace(-0.99,-0.0,20,endpoint=False)

t_alpha = []

for a in alpha:
    
    # Create linear regression object with a ridge coefficient 0.5
    ridge = Ridge(fit_intercept=True, alpha=a)

    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.33, shuffle=False)

    # Train the model using the training sets
    ridge.fit(X_train,Y_train)
    
    p = ridge.predict(X_test)

    # Compute RMSE and r2_score on training data
    r2score_train = r2_score(Y_test, p)
    rmse_train = np.sqrt(mean_squared_error(Y_test, p))
    
    # Now let's compute RMSE using 10-fold x-validation
    kf = KFold(n_splits=10, shuffle=False, random_state=None)
    xval_err = 0
    for train_index, test_index in kf.split(x):
        x_train, x_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        ridge.fit(x_train, y_train)
        p = ridge.predict(x_test)
        e = p-y_test
        xval_err += np.dot(e,e)

    rmse_10cv = np.sqrt(xval_err/len(x))
    
    print('{:.3f}\t {:.6f}\t\t {:.6f}\t\t {:.6f}'.format(a,r2score_train,rmse_train,rmse_10cv))
    
    row = [a, r2score_train]
    t_alpha.append(row)

cols = ['alpha', 'r2score_train']
t_alpha = pd.DataFrame(t_alpha, columns=cols)

t_alpha = t_alpha[t_alpha.r2score_train > -10]
print(t_alpha[t_alpha.r2score_train > -10])

# Plot outputs
# %matplotlib inline
pl.plot(t_alpha.alpha, t_alpha.r2score_train)
pl.ylabel('r2_score')
pl.xlabel('alpha')
pl.legend()
pl.show()

pl.savefig('wwo_model_results/ridge_all.png')
# Out:
# Ridge Regression
# alpha	 R2SCORE_train	 RMSE_train	 RMSE_10cv
#
# -0.990	 -1.881527		 0.112338		 0.560570
# -0.941	 -2.520533		 0.124171		 3.582428
# -0.891	 -4.342319		 0.152961		 1.705462
# -0.841	 -11.528969		 0.234247		 0.371880
# -0.792	 -165.913219		 0.854991		 0.308873
# -0.742	 -32.516210		 0.383128		 1.457207
# -0.693	 -8.161811		 0.200312		 0.190879
# -0.643	 -5160.088507		 4.754302		 0.101145
# -0.594	 -2.305928		 0.120327		 0.068097
# -0.544	 0.137116		 0.061474		 0.050972
# -0.495	 0.584847		 0.042640		 0.040645
# -0.446	 0.740515		 0.033711		 0.033907
# -0.396	 0.809001		 0.028922		 0.029327
# -0.346	 0.842220		 0.026287		 0.026158
# -0.297	 0.858551		 0.024890		 0.023967
# -0.247	 0.865831		 0.024240		 0.022482
# -0.198	 0.867732		 0.024068		 0.021533
# -0.148	 0.865732		 0.024249		 0.021060
# -0.099	 0.858068		 0.024932		 0.021447
# -0.049	 0.617481		 0.040930		 0.198409
#      alpha  r2score_train
# 0  -0.9900      -1.881527
# 1  -0.9405      -2.520533
# 2  -0.8910      -4.342319
# 6  -0.6930      -8.161811
# 8  -0.5940      -2.305928
# 9  -0.5445       0.137116
# 10 -0.4950       0.584847
# 11 -0.4455       0.740515
# 12 -0.3960       0.809001
# 13 -0.3465       0.842220
# 14 -0.2970       0.858551
# 15 -0.2475       0.865831
# 16 -0.1980       0.867732
# 17 -0.1485       0.865732
# 18 -0.0990       0.858068
# 19 -0.0495       0.617481

# %% [markdown]
# # Using Correlated Weather Variables

# %%
# Remove unused columns and reorder 
weather_dataset = weather_dataset[['precipMM', 'cond', 'humidity', 'cloudcover', 'dewPointC']]

# %%
# In order to do multiple regression we need to add a column of 1s for x0
x = weather_dataset.loc[:, weather_dataset.columns != 'precipMM'].values.tolist()
x = np.array([np.concatenate((v,[1])) for v in x])

# independent variable
y = weather_dataset['precipMM']

# %% [markdown]
# ## Ridge Regression using train_test_split

# %%
# Create ridge regression object with a ridge coefficient 0.5
ridge = Ridge(fit_intercept=True, alpha=-0.7)

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.33, shuffle=False)

# Train the model using the training set
ridge.fit(X_train,Y_train)
# Out:
# Ridge(alpha=-0.7, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
p = ridge.predict(X_test)

# Compute RMSE and r2_score on training data
r2score_train_corr = r2_score(Y_test, p)
rmse_train_corr = np.sqrt(mean_squared_error(Y_test, p))

print("R2 score", r2score_train_corr)
print("RMSE", rmse_train_corr)
# Out:
# R2 score 0.360382904867
# RMSE 0.052926857761

# %%
# We can view the regression coefficients
print( 'Regression Coefficients: \n', ridge.coef_)
# Out:
# Regression Coefficients:
#  [ 0.01010887  0.23360004  0.06397146  0.05014883 -0.        ]

# %%
# Plot outputs
# %matplotlib inline
pl.plot(p, Y_test,'ro')
pl.plot([0,0.4],[0,0.4], 'g-')
pl.xlabel('predicted')
pl.ylabel('real')
pl.show()

# %%
# Plot outputs
# %matplotlib inline
pl.plot(Y_test.index, p, label='predicted')
pl.plot(Y_test.index, Y_test, label='real')
pl.ylabel('precip')
pl.xlabel('date')
pl.legend()
pl.show()

# %% [markdown]
# ## Ridge Regression using 10-fold cross validation

# %%
# Now let's compute RMSE using 10-fold x-validation
kf = KFold(n_splits=10, shuffle=False, random_state=None)
xval_err = 0
for train_index, test_index in kf.split(x):
    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    ridge.fit(x_train, y_train)
    p = ridge.predict(x_test)
    e = p-y_test
    xval_err += np.dot(e,e)
    
rmse_10cv_corr = np.sqrt(xval_err/len(x))

# %%
method_name = 'Ridge Regression'
print('Method: %s' %method_name)
print('R2 score on training: %.6f'  %r2score_train_corr)
print('RMSE on training: %.6f'  %rmse_train_corr)
print('RMSE on 10-fold CV: %.6f'  %rmse_10cv_corr)
# Out:
# Method: Ridge Regression
# R2 score on training: 0.360383
# RMSE on training: 0.052927
# RMSE on 10-fold CV: 0.049804

# %% [markdown]
# ## Play with alpha

# %%
print('Ridge Regression')
print('alpha\t R2SCORE_train\t RMSE_train\t RMSE_10cv\n')
alpha = np.linspace(-0.99,-0.0,20,endpoint=False)

t_alpha = []

for a in alpha:
    
    # Create linear regression object with a ridge coefficient 0.5
    ridge = Ridge(fit_intercept=True, alpha=a)

    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.33, shuffle=False)

    # Train the model using the training sets
    ridge.fit(X_train,Y_train)
    
    p = ridge.predict(X_test)

    # Compute RMSE and r2_score on training data
    r2score_train = r2_score(Y_test, p)
    rmse_train = np.sqrt(mean_squared_error(Y_test, p))
    
    # Now let's compute RMSE using 10-fold x-validation
    kf = KFold(n_splits=10, shuffle=False, random_state=None)
    xval_err = 0
    for train_index, test_index in kf.split(x):
        x_train, x_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        ridge.fit(x_train, y_train)
        p = ridge.predict(x_test)
        e = p-y_test
        xval_err += np.dot(e,e)

    rmse_10cv = np.sqrt(xval_err/len(x))
    
    print('{:.3f}\t {:.6f}\t\t {:.6f}\t\t {:.6f}'.format(a,r2score_train,rmse_train,rmse_10cv))
    
    row = [a, r2score_train]
    t_alpha.append(row)

cols = ['alpha', 'r2score_train']
t_alpha = pd.DataFrame(t_alpha, columns=cols)

t_alpha = t_alpha[t_alpha.r2score_train > -10]
print(t_alpha[t_alpha.r2score_train > -10])

# Plot outputs
# %matplotlib inline
pl.plot(t_alpha.alpha, t_alpha.r2score_train)
pl.ylabel('r2_score')
pl.xlabel('alpha')
pl.legend()
pl.show()

pl.savefig('wwo_model_results/ridge_corr_all.png')
# Out:
# Ridge Regression
# alpha	 R2SCORE_train	 RMSE_train	 RMSE_10cv
#
# -0.990	 -1.019803		 0.094053		 1.657979
# -0.941	 -64.028070		 0.533662		 0.128858
# -0.891	 -0.413773		 0.078688		 0.075911
# -0.841	 0.176499		 0.060055		 0.061292
# -0.792	 0.298516		 0.055427		 0.054978
# -0.742	 0.342324		 0.053669		 0.051609
# -0.693	 0.362477		 0.052840		 0.049567
# -0.643	 0.373109		 0.052398		 0.048218
# -0.594	 0.379188		 0.052143		 0.047271
# -0.544	 0.382821		 0.051990		 0.046575
# -0.495	 0.385024		 0.051897		 0.046043
# -0.446	 0.386336		 0.051842		 0.045626
# -0.396	 0.387065		 0.051811		 0.045291
# -0.346	 0.387397		 0.051797		 0.045016
# -0.297	 0.387449		 0.051795		 0.044788
# -0.247	 0.387299		 0.051801		 0.044595
# -0.198	 0.386998		 0.051814		 0.044430
# -0.148	 0.386584		 0.051831		 0.044288
# -0.099	 0.386082		 0.051853		 0.044164
# -0.049	 0.385513		 0.051877		 0.044055
#      alpha  r2score_train
# 0  -0.9900      -1.019803
# 2  -0.8910      -0.413773
# 3  -0.8415       0.176499
# 4  -0.7920       0.298516
# 5  -0.7425       0.342324
# 6  -0.6930       0.362477
# 7  -0.6435       0.373109
# 8  -0.5940       0.379188
# 9  -0.5445       0.382821
# 10 -0.4950       0.385024
# 11 -0.4455       0.386336
# 12 -0.3960       0.387065
# 13 -0.3465       0.387397
# 14 -0.2970       0.387449
# 15 -0.2475       0.387299
# 16 -0.1980       0.386998
# 17 -0.1485       0.386584
# 18 -0.0990       0.386082
# 19 -0.0495       0.385513
